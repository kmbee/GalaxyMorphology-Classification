# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import os
import shutil
import glob
import random
from tqdm import tqdm
from numpy import *


import matplotlib.pyplot as plt

#do df si nacitame datovu tabulku Rozdelenia pravdepodobností pre klasifikácie pre každý obrazok galaxie


df = pd.read_csv('training_solutions_rev1.csv')


#df.iloc[:, 1:] = df.iloc[:, 1:].round(2)

display(df)

#pomocou rozhodovacieho algoritmu prejdeme vsetky odpovede a na zaklade diagramu ktory popisuje data (https://data.galaxyzoo.org/gz_trees/gz_trees.html) 
# priradime kazdej galaxii jej typ... rozhodujeme sa klasickym porovnavanim odopvedi, vacsie percento vyhrava

"""tabulka = ["completely round" == 0,
           "in between"          == 1,
           "cigar-shaped"        == 2, vyhodit 
           "on edge"             == 3,
           "spiral"              == 4,
           "different shape"     == 5, vyhodit
           "star or artifact"    == 6] vyhodit""" 

def shape_of_gal(dataframe, gal_id):
    
    galaxy_id = [gal_id]
    
    selected_row = dataframe.loc[dataframe['GalaxyID'].isin(galaxy_id)]
    

    class_1 = selected_row[["Class1.1" , 'Class1.2' , 'Class1.3']].astype(float)
    Q_1 = class_1.idxmax(axis=1)
    Q_1 = Q_1.to_string()
    Q_1 = Q_1[Q_1.find('C'):]
    
    
    
    
    if Q_1 == "Class1.1":
        class_7 = selected_row[["Class7.1" , 'Class7.2' , 'Class7.3']].astype(float)
        Q_7 = class_7.idxmax(axis=1)
        Q_7 = Q_7.to_string()
        Q_7 = Q_7[Q_7.find('C'):]
        
        if Q_7 == "Class7.1":
            #print("completely round")
            vysledok = "completely_round"
        elif Q_7 == "Class7.2":
            #print("in between")
            vysledok = "in_between"
        else:
            #print("cigar-shaped")
            vysledok = "cigar_shaped"
        
    elif Q_1 == "Class1.2":
        class_2 = selected_row[["Class2.1" , 'Class2.2']].astype(float)
        Q_2 = class_2.idxmax(axis=1)
        Q_2 = Q_2.to_string()
        Q_2 = Q_2[Q_2.find('C'):]
        
        if Q_2 == "Class2.1":
            #print("on edge")
            vysledok = "on_edge"
        else:
            class_4 = selected_row[["Class4.1" , 'Class4.2']].astype(float)
            Q_4 = class_4.idxmax(axis=1)
            Q_4 = Q_4.to_string()
            Q_4 = Q_4[Q_4.find('C'):]
            
            if Q_4 == "Class4.1":
                #print("spiral")
                vysledok = "spiral"
            else: 
                #print("different shape")
                vysledok = "different_shape"
        
      

    else:
        #print("star or artifact")
        vysledok = "star_or_artifact"
        
    return vysledok


def assign_gal_type(dataframe):
       
    sel = dataframe.values
    ids = sel[:,0].astype(int).astype(str)   
    vysledky = []
    
    for i in tqdm(ids):
        x = shape_of_gal(dataframe, i)
        vysledky.append(x)
    vysledky = np.array(vysledky)
    return vysledky    


types =  assign_gal_type(df)


df['type'] = types

#df.to_csv('df_with_types.csv', index=False)

# vypiseme, kolko ktorych tried obsahuje cely dataset
unique, counts = np.unique(types, return_counts=True)
print (np.asarray((unique, counts)).T)

fig = plt.figure(figsize = (15, 7)) 
  
# creating the bar plot 
plt.bar(unique, counts, color ='green',  
        width = 0.4)

  
plt.xlabel("Typ galaxie") 
plt.ylabel("Počet vývskytu v celom datasete") 
plt.title("Rozloženie typov galaxií v celom datasete") 
plt.show()
# Out:
#        GalaxyID  Class1.1  Class1.2  Class1.3  Class2.1  Class2.2  Class3.1  \
# 0        100008  0.383147  0.616853  0.000000  0.000000  0.616853  0.038452
# 1        100023  0.327001  0.663777  0.009222  0.031178  0.632599  0.467370
# 2        100053  0.765717  0.177352  0.056931  0.000000  0.177352  0.000000
# 3        100078  0.693377  0.238564  0.068059  0.000000  0.238564  0.109493
# 4        100090  0.933839  0.000000  0.066161  0.000000  0.000000  0.000000
# ...         ...       ...       ...       ...       ...       ...       ...
# 61573    999948  0.510379  0.489621  0.000000  0.059207  0.430414  0.000000
# 61574    999950  0.901216  0.098784  0.000000  0.000000  0.098784  0.000000
# 61575    999958  0.202841  0.777376  0.019783  0.116962  0.660414  0.067245
# 61576    999964  0.091000  0.909000  0.000000  0.045450  0.863550  0.022452
# 61577    999967  0.767000  0.140000  0.093000  0.000000  0.140000  0.000000
#
#        Class3.2  Class4.1  Class4.2  ...  Class9.3  Class10.1  Class10.2  \
# 0      0.578401  0.418398  0.198455  ...  0.000000   0.279952   0.138445
# 1      0.165229  0.591328  0.041271  ...  0.018764   0.000000   0.131378
# 2      0.177352  0.000000  0.177352  ...  0.000000   0.000000   0.000000
# 3      0.129071  0.189098  0.049466  ...  0.000000   0.094549   0.000000
# 4      0.000000  0.000000  0.000000  ...  0.000000   0.000000   0.000000
# ...         ...       ...       ...  ...       ...        ...        ...
# 61573  0.430414  0.226257  0.204157  ...  0.000000   0.226257   0.000000
# 61574  0.098784  0.000000  0.098784  ...  0.000000   0.000000   0.000000
# 61575  0.593168  0.140022  0.520391  ...  0.000000   0.000000   0.090673
# 61576  0.841098  0.795330  0.068220  ...  0.000000   0.068398   0.318132
# 61577  0.140000  0.023380  0.116620  ...  0.000000   0.023380   0.000000
#
#        Class10.3  Class11.1  Class11.2  Class11.3  Class11.4  Class11.5  \
# 0       0.000000   0.000000   0.092886   0.000000   0.000000        0.0
# 1       0.459950   0.000000   0.591328   0.000000   0.000000        0.0
# 2       0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# 3       0.094549   0.189098   0.000000   0.000000   0.000000        0.0
# 4       0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# ...          ...        ...        ...        ...        ...        ...
# 61573   0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# 61574   0.000000   0.000000   0.000000   0.000000   0.000000        0.0
# 61575   0.049349   0.000000   0.067726   0.000000   0.000000        0.0
# 61576   0.408799   0.227464   0.408799   0.090668   0.023065        0.0
# 61577   0.000000   0.000000   0.000000   0.000000   0.000000        0.0
#
#        Class11.6
# 0       0.325512
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 61573   0.226257
# 61574   0.000000
# 61575   0.072296
# 61576   0.045334
# 61577   0.023380
#
# [61578 rows x 38 columns]
# 100%|██████████| 61578/61578 [03:49<00:00, 268.23it/s]
# [['cigar_shaped' '1586']
#  ['completely_round' '12039']
#  ['different_shape' '12930']
#  ['in_between' '13068']
#  ['on_edge' '6680']
#  ['spiral' '15216']
#  ['star_or_artifact' '59']]

# %%
print("pocet galaxii v celom datasete na zaciatku: ", len(df))

#kedze nechceme nerozhodne zaklasifikovane galaxie, odstranime z celeho datasetu tie, pri ktorych si boli ludia isti na menej ako 50%
#df_with_types = df
#df = pd.read_csv('df_with_types.csv')

df = df[(df['Class1.1'] >= 0.50) |
        (df['Class1.2'] >= 0.50)]

df = df[(df['Class7.1'] >= 0.50) | 
        (df['Class7.2'] >= 0.50) |
        (df['Class2.1'] >= 0.50) |
        (df['Class4.1'] >= 0.50) ]

print("pocet galaxii v celom datasete po odfiltrovani tych s mensou pravdepodobnostou ze patria do jednej z tried ako 50%: ", len(df))

types = df['type']

unique, counts = np.unique(types, return_counts=True)
print (np.asarray((unique, counts)).T)


# vidime ze ked sme nehcali len galaxie, ktore boli klasifikovane z vacsou presnostou ako 0.5 tak sa nam dataset zmensil z 61578 na 31944
# teraz si este zmensime dataset tak, ze odstranime tie typy, ktorych klasifikacia nie je cielom nasej prace, chceme nechat iba
# "Completely round", "In between", "on edge" a "spiral"


columns_mapper = {
    'GalaxyID': 'GalaxyID',
    'Class7.1': 'completely_round',
    'Class7.2': 'in_between',
    'Class2.1': 'on_edge',
    'Class4.1': 'spiral'
}

columns = list(columns_mapper.values())
df = df.rename(columns=columns_mapper)[columns]
#df.set_index('GalaxyID', inplace=True)
display(df)


# teraz uz mame len 4 atributy pre kazdy typ galaxie a kazdy obsahuje percentualnu pravdepodobnost, ze dany obrazok patri do tej triedy
# teraz si mozeme rozdelit data na trenovaciu a testovaciu cast
# Out:
# pocet galaxii v celom datasete na zaciatku:  61578
# pocet galaxii v celom datasete po odfiltrovani tych s mensou pravdepodobnostou ze patria do jednej z tried ako 50%:  31944
# [['completely_round' 8436]
#  ['in_between' 8069]
#  ['on_edge' 5042]
#  ['spiral' 10397]]
#        GalaxyID  completely_round  in_between   on_edge    spiral
# 1        100023          0.000000    0.135082  0.031178  0.591328
# 2        100053          0.000000    0.741864  0.000000  0.000000
# 5        100122          0.066807    0.663691  0.000000  0.000000
# 8        100134          0.010917    0.010917  0.021751  0.546491
# 9        100143          0.000000    0.000000  0.730157  0.000000
# ...         ...               ...         ...       ...       ...
# 61566    999795          0.055718    0.074160  0.066500  0.550301
# 61568    999875          0.000000    0.007985  0.207551  0.722483
# 61569    999890          0.000000    0.000000  0.691971  0.000000
# 61576    999964          0.045500    0.045500  0.045450  0.795330
# 61577    999967          0.069797    0.674193  0.000000  0.023380
#
# [31944 rows x 5 columns]

# %%
# vizualizujeme ako mame rozdeleny dataset teraz, kolko akych typov galaxii


blacha = df[["completely_round", "in_between", "on_edge", "spiral"]]
#display(df)
#max_value = blacha.max(axis=1)

typy_gal = blacha.idxmax(axis=1)

unique, counts = np.unique(typy_gal, return_counts=True)
print (np.asarray((unique, counts)).T)

fig = plt.figure(figsize = (10, 10)) 
  
# creating the bar plot 

plt.pie(counts, autopct='%1.1f%%', startangle=90)
plt.legend(counts, labels=unique, loc='center left', bbox_to_anchor=(-0.1, 1.),
           fontsize=15)
  
plt.show()
# Out:
# [['completely_round' 8436]
#  ['in_between' 8069]
#  ['on_edge' 5042]
#  ['spiral' 10397]]
# <ipython-input-15-42ae7a6a51af>:18: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend(counts, labels=unique, loc='center left', bbox_to_anchor=(-0.1, 1.),

# %%
#rozdelime si data na trenovaci dataset a testovaci v pomere 80:20 a vytvorime nove priecinky kde skopirujeme obrazky na trenovanie a testovanie modelu


df_trenovacia, df_testovacia = train_test_split(df, test_size=.2, random_state=42)



def vytvor_testovaciu_mnozinu():
    
    os.mkdir('testovacie_data')
    
    #to_be_moved = random.sample(glob.glob("./images_training_rev1/*.jpg"), 6944)
    
    images_names = df_testovacia["GalaxyID"]
    
    to_be_moved = []
    
    for i in images_names:
        to_be_moved.append('./images_training_rev1/' + str(i) + ".jpg")

    for f in enumerate(to_be_moved, 1):
        dest = "./testovacie_data"
        shutil.copy(f[1], dest)
        
    print("TESTOVACIA mnozina vytvorena, velkost: ", len(os.listdir('./testovacie_data')))

vytvor_testovaciu_mnozinu()



def vytvor_trenovaciu_mnozinu():
    
    os.mkdir('trenovacie_data')
    
    #to_be_moved = random.sample(glob.glob("./images_training_rev1/*.jpg"), 6944)
    
    images_names = df_trenovacia["GalaxyID"]
    
    to_be_moved = []
    
    for i in images_names:
        to_be_moved.append('./images_training_rev1/' + str(i) + ".jpg")

    for f in enumerate(to_be_moved, 1):
        dest = "./trenovacie_data"
        shutil.copy(f[1], dest)
        
    print("TRENOVACIA mnozina vytvorena, velkost: ", len(os.listdir('./trenovacie_data')))

vytvor_trenovaciu_mnozinu()


#vymaz z celeho datasetu testovacie obrazky a ostane nam trenovaci_dataset
# def vymaz_testovacie_obrazky():
#     test_images_names = os.listdir('./testovacie_data')

#     to_be_moved = []
#     for i in test_images_names:
#         to_be_moved.append('./images_training_rev1/' + str(i))
        


#     for file in to_be_moved:
#         #print(file)
#         if os.path.exists(file):
#             os.remove(file)
#     print("trenovacia mnozina vytvorena, velkost: ", len(os.listdir('./images_training_rev1')))

# vymaz_testovacie_obrazky()

# %%
############## cast 2 priprava obrazkov na modelovanie

from skimage.transform import resize
from tqdm import tqdm
import matplotlib.pyplot as plt
#%matplotlib inline



len(df_trenovacia)

df_train, df_test = train_test_split(df_trenovacia, test_size=.2) #rozdelenie na trenovaciu a validacnu vzorku

print(df_train.shape, df_test.shape)

print(df.shape)



ORIG_SHAPE = (424,424)  #originalna velkost obrazkov
CROP_SIZE = (256,256)   #zaijumaa nas hlavne stred, tak si ich orezeme
IMG_SHAPE = (64,64,3)   #orezenym obrazkom znizime rozlisenie na 64x64x3... 3 to predstavuje RGB


#funkcia na upravu obrazku do pozadovaneho stavu
def get_image(path, x1,y1, shape, crop_size):
    x = plt.imread(path)
    x = x[x1:x1+crop_size[0], y1:y1+crop_size[1]]
    x = resize(x, shape)
    x = x/255.
    return x

#funkcia na upravu vsetkych obrazkov z daneho datasetu na numpy polia , aby ich pocitac vedel precitat
def get_all_images(dataframe, shape=IMG_SHAPE, crop_size=CROP_SIZE):
    x1 = (ORIG_SHAPE[0]-CROP_SIZE[0])//2
    y1 = (ORIG_SHAPE[1]-CROP_SIZE[1])//2
   
    sel = dataframe.values
    ids = sel[:,0].astype(int).astype(str)
    y_batch = sel[:,1:]
    x_batch = []
    for i in tqdm(ids):
        x = get_image('./trenovacie_data/'+i+'.jpg', x1,y1, shape=shape, crop_size=crop_size)
        x_batch.append(x)
    x_batch = np.array(x_batch)
    #x_batch = np.asarray(x_batch).astype(np.float32)
    return x_batch, y_batch

X_train, y_train = get_all_images(df_train)
X_test, y_test = get_all_images(df_test)

y_train = np.asarray(y_train).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

print(X_train.shape, y_train.shape)


#priklad obrazku po uprave
plt.pcolormesh(X_train[12,:,:,0])
print(plt.colorbar())
# Out:
#   0%|          | 1/20444 [00:00<36:05,  9.44it/s]
# (20444, 5) (5111, 5)
# (31944, 5)
# 100%|██████████| 20444/20444 [07:29<00:00, 45.49it/s]
# 100%|██████████| 5111/5111 [01:40<00:00, 50.86it/s]
# (20444, 64, 64, 3) (20444, 4)
# <matplotlib.colorbar.Colorbar object at 0x7f5d1da59a60>

# %%
### vytvaranie modelu

import tensorflow as tf

from tensorflow.keras.preprocessing.image import ImageDataGenerator

#from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten
from tensorflow.keras.layers import Dense, BatchNormalization, GlobalMaxPooling2D
from tensorflow.keras import backend as K
#from tensorflow.keras.optimizers import Adam
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

model = Sequential()
model.add(Conv2D(256, (3, 3), input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], 3)))
model.add(Conv2D(256, (3, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Conv2D(128, (3, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Conv2D(128, (3, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(GlobalMaxPooling2D())


model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(4))
model.add(Activation('sigmoid'))

#adam = Adam()
#model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

model.compile(loss='binary_crossentropy', 
              optimizer='adamax', 
              metrics=[tf.keras.metrics.RootMeanSquaredError(name='root_mean_squared_error')])
print(model.summary())

# checkpoint_path = "training_1/cp.ckpt"
# checkpoint_dir = os.path.dirname(checkpoint_path)

# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
#                                                  save_weights_only=True,
#                                                  verbose=1)

saved_model = "model_exp1.hdf5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(saved_model, 
                                                monitor='val_root_mean_squared_error', 
                                                verbose=1, 
                                                save_best_only=True, mode='min')



train_datagen = ImageDataGenerator(
        rotation_range=90,
        horizontal_flip=True)

batch_size = 128
history = model.fit(train_datagen.flow(X_train,y_train,
                                       shuffle=False),
                    epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint])

# batch_size = 128
# history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), callbacks=[checkpoint])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 256)       7168
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 256)       590080
# _________________________________________________________________
# activation (Activation)      (None, 60, 60, 256)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 256)       590080
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 128)       295040
# _________________________________________________________________
# activation_1 (Activation)    (None, 26, 26, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 128)         147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 128)         0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 516
# _________________________________________________________________
# activation_6 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 1,827,588
# Trainable params: 1,827,588
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.5113 - root_mean_squared_error: 0.3046
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.29783, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 47ms/step - loss: 0.5113 - root_mean_squared_error: 0.3046 - val_loss: 0.4993 - val_root_mean_squared_error: 0.2978
# Epoch 2/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.4929 - root_mean_squared_error: 0.2953
# Epoch 00002: val_root_mean_squared_error improved from 0.29783 to 0.26843, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 47ms/step - loss: 0.4928 - root_mean_squared_error: 0.2953 - val_loss: 0.4433 - val_root_mean_squared_error: 0.2684
# Epoch 3/50
# 639/639 [==============================] - ETA: 0s - loss: 0.4111 - root_mean_squared_error: 0.2461
# Epoch 00003: val_root_mean_squared_error improved from 0.26843 to 0.20659, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 47ms/step - loss: 0.4111 - root_mean_squared_error: 0.2461 - val_loss: 0.3570 - val_root_mean_squared_error: 0.2066
# Epoch 4/50
# 639/639 [==============================] - ETA: 0s - loss: 0.3560 - root_mean_squared_error: 0.2023
# Epoch 00004: val_root_mean_squared_error improved from 0.20659 to 0.17787, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 47ms/step - loss: 0.3560 - root_mean_squared_error: 0.2023 - val_loss: 0.3309 - val_root_mean_squared_error: 0.1779
# Epoch 5/50
# 639/639 [==============================] - ETA: 0s - loss: 0.3278 - root_mean_squared_error: 0.1744
# Epoch 00005: val_root_mean_squared_error improved from 0.17787 to 0.15978, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.3278 - root_mean_squared_error: 0.1744 - val_loss: 0.3116 - val_root_mean_squared_error: 0.1598
# Epoch 6/50
# 639/639 [==============================] - ETA: 0s - loss: 0.3148 - root_mean_squared_error: 0.1606
# Epoch 00006: val_root_mean_squared_error improved from 0.15978 to 0.14001, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 48ms/step - loss: 0.3148 - root_mean_squared_error: 0.1606 - val_loss: 0.2951 - val_root_mean_squared_error: 0.1400
# Epoch 7/50
# 639/639 [==============================] - ETA: 0s - loss: 0.3063 - root_mean_squared_error: 0.1511
# Epoch 00007: val_root_mean_squared_error improved from 0.14001 to 0.13763, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.3063 - root_mean_squared_error: 0.1511 - val_loss: 0.2934 - val_root_mean_squared_error: 0.1376
# Epoch 8/50
# 639/639 [==============================] - ETA: 0s - loss: 0.3019 - root_mean_squared_error: 0.1463
# Epoch 00008: val_root_mean_squared_error improved from 0.13763 to 0.12644, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 48ms/step - loss: 0.3019 - root_mean_squared_error: 0.1463 - val_loss: 0.2843 - val_root_mean_squared_error: 0.1264
# Epoch 9/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2967 - root_mean_squared_error: 0.1398
# Epoch 00009: val_root_mean_squared_error improved from 0.12644 to 0.12633, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2967 - root_mean_squared_error: 0.1398 - val_loss: 0.2835 - val_root_mean_squared_error: 0.1263
# Epoch 10/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.2924 - root_mean_squared_error: 0.1351
# Epoch 00010: val_root_mean_squared_error did not improve from 0.12633
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2924 - root_mean_squared_error: 0.1350 - val_loss: 0.2881 - val_root_mean_squared_error: 0.1325
# Epoch 11/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2916 - root_mean_squared_error: 0.1338
# Epoch 00011: val_root_mean_squared_error improved from 0.12633 to 0.11723, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2916 - root_mean_squared_error: 0.1338 - val_loss: 0.2774 - val_root_mean_squared_error: 0.1172
# Epoch 12/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2878 - root_mean_squared_error: 0.1290
# Epoch 00012: val_root_mean_squared_error improved from 0.11723 to 0.11469, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2878 - root_mean_squared_error: 0.1290 - val_loss: 0.2760 - val_root_mean_squared_error: 0.1147
# Epoch 13/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2868 - root_mean_squared_error: 0.1274
# Epoch 00013: val_root_mean_squared_error improved from 0.11469 to 0.11461, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2868 - root_mean_squared_error: 0.1274 - val_loss: 0.2763 - val_root_mean_squared_error: 0.1146
# Epoch 14/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2862 - root_mean_squared_error: 0.1265
# Epoch 00014: val_root_mean_squared_error did not improve from 0.11461
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2862 - root_mean_squared_error: 0.1265 - val_loss: 0.2773 - val_root_mean_squared_error: 0.1176
# Epoch 15/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2855 - root_mean_squared_error: 0.1260
# Epoch 00015: val_root_mean_squared_error did not improve from 0.11461
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2855 - root_mean_squared_error: 0.1260 - val_loss: 0.2792 - val_root_mean_squared_error: 0.1208
# Epoch 16/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2829 - root_mean_squared_error: 0.1222
# Epoch 00016: val_root_mean_squared_error did not improve from 0.11461
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2829 - root_mean_squared_error: 0.1222 - val_loss: 0.2773 - val_root_mean_squared_error: 0.1180
# Epoch 17/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2823 - root_mean_squared_error: 0.1217
# Epoch 00017: val_root_mean_squared_error improved from 0.11461 to 0.10856, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2823 - root_mean_squared_error: 0.1217 - val_loss: 0.2714 - val_root_mean_squared_error: 0.1086
# Epoch 18/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2823 - root_mean_squared_error: 0.1213
# Epoch 00018: val_root_mean_squared_error did not improve from 0.10856
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2823 - root_mean_squared_error: 0.1213 - val_loss: 0.2737 - val_root_mean_squared_error: 0.1122
# Epoch 19/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2811 - root_mean_squared_error: 0.1202
# Epoch 00019: val_root_mean_squared_error did not improve from 0.10856
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2811 - root_mean_squared_error: 0.1202 - val_loss: 0.2733 - val_root_mean_squared_error: 0.1106
# Epoch 20/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2806 - root_mean_squared_error: 0.1189
# Epoch 00020: val_root_mean_squared_error did not improve from 0.10856
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2806 - root_mean_squared_error: 0.1189 - val_loss: 0.2742 - val_root_mean_squared_error: 0.1125
# Epoch 21/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2807 - root_mean_squared_error: 0.1196
# Epoch 00021: val_root_mean_squared_error did not improve from 0.10856
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2807 - root_mean_squared_error: 0.1196 - val_loss: 0.2727 - val_root_mean_squared_error: 0.1098
# Epoch 22/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2793 - root_mean_squared_error: 0.1176
# Epoch 00022: val_root_mean_squared_error did not improve from 0.10856
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2793 - root_mean_squared_error: 0.1176 - val_loss: 0.2721 - val_root_mean_squared_error: 0.1098
# Epoch 23/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2782 - root_mean_squared_error: 0.1161
# Epoch 00023: val_root_mean_squared_error improved from 0.10856 to 0.10769, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2782 - root_mean_squared_error: 0.1161 - val_loss: 0.2712 - val_root_mean_squared_error: 0.1077
# Epoch 24/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2789 - root_mean_squared_error: 0.1170
# Epoch 00024: val_root_mean_squared_error improved from 0.10769 to 0.10424, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2789 - root_mean_squared_error: 0.1170 - val_loss: 0.2688 - val_root_mean_squared_error: 0.1042
# Epoch 25/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2785 - root_mean_squared_error: 0.1162
# Epoch 00025: val_root_mean_squared_error did not improve from 0.10424
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2785 - root_mean_squared_error: 0.1162 - val_loss: 0.2722 - val_root_mean_squared_error: 0.1090
# Epoch 26/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.2774 - root_mean_squared_error: 0.1147
# Epoch 00026: val_root_mean_squared_error did not improve from 0.10424
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2774 - root_mean_squared_error: 0.1147 - val_loss: 0.2730 - val_root_mean_squared_error: 0.1103
# Epoch 27/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2773 - root_mean_squared_error: 0.1148
# Epoch 00027: val_root_mean_squared_error did not improve from 0.10424
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2773 - root_mean_squared_error: 0.1148 - val_loss: 0.2699 - val_root_mean_squared_error: 0.1057
# Epoch 28/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2764 - root_mean_squared_error: 0.1133
# Epoch 00028: val_root_mean_squared_error improved from 0.10424 to 0.10396, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2764 - root_mean_squared_error: 0.1133 - val_loss: 0.2688 - val_root_mean_squared_error: 0.1040
# Epoch 29/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2767 - root_mean_squared_error: 0.1139
# Epoch 00029: val_root_mean_squared_error did not improve from 0.10396
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2767 - root_mean_squared_error: 0.1139 - val_loss: 0.2778 - val_root_mean_squared_error: 0.1182
# Epoch 30/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2758 - root_mean_squared_error: 0.1127
# Epoch 00030: val_root_mean_squared_error improved from 0.10396 to 0.10262, saving model to model_exp1.hdf5
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2758 - root_mean_squared_error: 0.1127 - val_loss: 0.2680 - val_root_mean_squared_error: 0.1026
# Epoch 31/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2757 - root_mean_squared_error: 0.1123
# Epoch 00031: val_root_mean_squared_error did not improve from 0.10262
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2757 - root_mean_squared_error: 0.1123 - val_loss: 0.2696 - val_root_mean_squared_error: 0.1053
# Epoch 32/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2757 - root_mean_squared_error: 0.1125
# Epoch 00032: val_root_mean_squared_error improved from 0.10262 to 0.10243, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2757 - root_mean_squared_error: 0.1125 - val_loss: 0.2681 - val_root_mean_squared_error: 0.1024
# Epoch 33/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2754 - root_mean_squared_error: 0.1120
# Epoch 00033: val_root_mean_squared_error did not improve from 0.10243
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2754 - root_mean_squared_error: 0.1120 - val_loss: 0.2684 - val_root_mean_squared_error: 0.1038
# Epoch 34/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2746 - root_mean_squared_error: 0.1107
# Epoch 00034: val_root_mean_squared_error improved from 0.10243 to 0.09850, saving model to model_exp1.hdf5
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2746 - root_mean_squared_error: 0.1107 - val_loss: 0.2660 - val_root_mean_squared_error: 0.0985
# Epoch 35/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2750 - root_mean_squared_error: 0.1113
# Epoch 00035: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2750 - root_mean_squared_error: 0.1113 - val_loss: 0.2678 - val_root_mean_squared_error: 0.1027
# Epoch 36/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.2743 - root_mean_squared_error: 0.1103
# Epoch 00036: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2743 - root_mean_squared_error: 0.1103 - val_loss: 0.2687 - val_root_mean_squared_error: 0.1035
# Epoch 37/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.2738 - root_mean_squared_error: 0.1094
# Epoch 00037: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2739 - root_mean_squared_error: 0.1095 - val_loss: 0.2692 - val_root_mean_squared_error: 0.1041
# Epoch 38/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2738 - root_mean_squared_error: 0.1093
# Epoch 00038: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2738 - root_mean_squared_error: 0.1093 - val_loss: 0.2673 - val_root_mean_squared_error: 0.1018
# Epoch 39/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.2731 - root_mean_squared_error: 0.1084
# Epoch 00039: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2731 - root_mean_squared_error: 0.1084 - val_loss: 0.2675 - val_root_mean_squared_error: 0.1017
# Epoch 40/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2734 - root_mean_squared_error: 0.1087
# Epoch 00040: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2734 - root_mean_squared_error: 0.1087 - val_loss: 0.2731 - val_root_mean_squared_error: 0.1118
# Epoch 41/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2731 - root_mean_squared_error: 0.1085
# Epoch 00041: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2731 - root_mean_squared_error: 0.1085 - val_loss: 0.2696 - val_root_mean_squared_error: 0.1046
# Epoch 42/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2730 - root_mean_squared_error: 0.1085
# Epoch 00042: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2730 - root_mean_squared_error: 0.1085 - val_loss: 0.2683 - val_root_mean_squared_error: 0.1040
# Epoch 43/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2724 - root_mean_squared_error: 0.1074
# Epoch 00043: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2724 - root_mean_squared_error: 0.1074 - val_loss: 0.2672 - val_root_mean_squared_error: 0.1016
# Epoch 44/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2719 - root_mean_squared_error: 0.1065
# Epoch 00044: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2719 - root_mean_squared_error: 0.1065 - val_loss: 0.2668 - val_root_mean_squared_error: 0.1005
# Epoch 45/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2721 - root_mean_squared_error: 0.1070
# Epoch 00045: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 31s 48ms/step - loss: 0.2721 - root_mean_squared_error: 0.1070 - val_loss: 0.2667 - val_root_mean_squared_error: 0.1007
# Epoch 46/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2723 - root_mean_squared_error: 0.1073
# Epoch 00046: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2723 - root_mean_squared_error: 0.1073 - val_loss: 0.2659 - val_root_mean_squared_error: 0.0991
# Epoch 47/50
# 638/639 [============================>.] - ETA: 0s - loss: 0.2718 - root_mean_squared_error: 0.1067
# Epoch 00047: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2718 - root_mean_squared_error: 0.1068 - val_loss: 0.2665 - val_root_mean_squared_error: 0.1007
# Epoch 48/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2715 - root_mean_squared_error: 0.1061
# Epoch 00048: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2715 - root_mean_squared_error: 0.1061 - val_loss: 0.2659 - val_root_mean_squared_error: 0.0993
# Epoch 49/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2719 - root_mean_squared_error: 0.1064
# Epoch 00049: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 47ms/step - loss: 0.2719 - root_mean_squared_error: 0.1064 - val_loss: 0.2704 - val_root_mean_squared_error: 0.1073
# Epoch 50/50
# 639/639 [==============================] - ETA: 0s - loss: 0.2716 - root_mean_squared_error: 0.1062
# Epoch 00050: val_root_mean_squared_error did not improve from 0.09850
# 639/639 [==============================] - 30s 48ms/step - loss: 0.2716 - root_mean_squared_error: 0.1062 - val_loss: 0.2696 - val_root_mean_squared_error: 0.1057

# %%
######## vizualizacia procesu trenovanie modelu na trenovacej a validacnej mnozine

import matplotlib.pyplot as plt

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model root_mean_squared_error')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend([ 'val', 'train',], loc='upper left')
plt.show()

# loss, acc = model.evaluate(X_test, y_test, verbose=1)
# print("Untrained model, accuracy: {:5.2f}%".format(100 * acc))

scores = model.evaluate(X_test, y_test, verbose=1)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2660 - root_mean_squared_error: 0.0985
# root_mean_squared_error: 9.85%

# %%
############ predikovanie galaxii

from tensorflow.keras.models import load_model

def test_image_generator(ids, shape=IMG_SHAPE):
    x1 = (ORIG_SHAPE[0]-CROP_SIZE[0])//2
    y1 = (ORIG_SHAPE[1]-CROP_SIZE[1])//2
    x_batch = []
    for i in ids:
        x = get_image('./testovacie_data/'+i, x1, y1, shape=IMG_SHAPE, crop_size=CROP_SIZE)
        x_batch.append(x)
    x_batch = np.array(x_batch)
    return x_batch


val_files = os.listdir('./testovacie_data/')
val_predictions = []
N_val = len(val_files)

model = load_model('model_exp1.hdf5')

for i in tqdm(np.arange(0, N_val, batch_size)):
    if i+batch_size > N_val:
        upper = N_val
    else:
        upper = i+batch_size
    X = test_image_generator(val_files[i:upper])
    y_pred = model.predict(X)
    val_predictions.append(y_pred)

val_predictions = np.array(val_predictions)
Y_pred = np.vstack(val_predictions)
ids = np.array([v.split('.')[0] for v in val_files]).reshape(len(val_files),1)
submission_df = pd.DataFrame(np.hstack((ids, Y_pred)), columns=df_testovacia.columns)
submission_df = submission_df.sort_values(by=['GalaxyID'])
submission_df.to_csv('sample_sub_testovacie_data_exp1.csv', index=False)

print(submission_df.head())
# Out:
# 100%|██████████| 50/50 [01:04<00:00,  1.28s/it]
#      GalaxyID completely_round    in_between      on_edge       spiral
# 2421   100288       0.06665861    0.60887516  0.017716886   0.08590609
# 4150   100322    2.9731802e-05  0.0010714403   0.72299236  0.019549223
# 4472   100986    0.00090029486   0.029904768    0.6141734   0.04868294
# 3142   101074       0.04058771    0.12077948  0.020569568    0.6597718
# 1782   101092         0.333599    0.48857078  0.010432413  0.039272577

# %%
################# VYHODNOTENIE

#submission = pd.read_csv('sample_sub_testovacie_data_exp1.csv')

submission = submission_df

display(submission)

submission_ids = submission["GalaxyID"].tolist()

#print(submission_ids)

original_training_data = pd.read_csv('./training_solutions_rev1.csv')

test_df = original_training_data.loc[original_training_data['GalaxyID'].isin(submission_ids)]

test_df['GalaxyID'] = test_df['GalaxyID'].astype(str)


columns_mapper = {
    'GalaxyID': 'GalaxyID',
    'Class7.1': 'completely_round',
    'Class7.2': 'in_between',
    'Class2.1': 'on_edge',
    'Class4.1': 'spiral'
}

columns = list(columns_mapper.values())
test_df = test_df.rename(columns=columns_mapper)[columns]

#display(test_df)
#display(submission)



submission.set_index('GalaxyID', inplace=True)
test_df.set_index('GalaxyID', inplace=True)

predikovana = submission.astype(float).idxmax(axis=1)
testovacia = test_df.astype(float).idxmax(axis=1)

unique, counts = np.unique(testovacia, return_counts=True)
print (np.asarray((unique, counts)).T)
unique, counts = np.unique(predikovana, return_counts=True)
print (np.asarray((unique, counts)).T)
# Out:
#      GalaxyID completely_round    in_between      on_edge       spiral
# 2421   100288       0.06665861    0.60887516  0.017716886   0.08590609
# 4150   100322    2.9731802e-05  0.0010714403   0.72299236  0.019549223
# 4472   100986    0.00090029486   0.029904768    0.6141734   0.04868294
# 3142   101074       0.04058771    0.12077948  0.020569568    0.6597718
# 1782   101092         0.333599    0.48857078  0.010432413  0.039272577
# ...       ...              ...           ...          ...          ...
# 5466   999264      0.014306429   0.048666503  0.032023262    0.7816908
# 2224   999293      0.024702534    0.62530386  0.040265106   0.07490438
# 1236   999475      0.045161575     0.5264925   0.12478392  0.044845708
# 46     999569      0.099684544     0.6474564  0.018047651   0.03169502
# 3827   999890     6.300427e-05   0.005185793    0.6896341  0.019066514
#
# [6389 rows x 5 columns]
# [['completely_round' 1700]
#  ['in_between' 1546]
#  ['on_edge' 1040]
#  ['spiral' 2103]]
# [['completely_round' 1614]
#  ['in_between' 1627]
#  ['on_edge' 1063]
#  ['spiral' 2085]]
# <ipython-input-26-5d54153c2695>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['GalaxyID'] = test_df['GalaxyID'].astype(str)

# %%
#################### METRIKY 

import seaborn as sn
from sklearn.metrics import precision_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix



import os
import shutil
import glob
import random
from tqdm import tqdm
from numpy import *


import matplotlib.pyplot as plt
import seaborn as sns

def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    
    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in 
                  zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy,precision,recall,f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,
                cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)
    
    if title:
        plt.title(title)

conf_mat = confusion_matrix(testovacia, predikovana)       
print(conf_mat)
#sn.heatmap(conf_mat, annot=True)

categories = ['completely round', 'in between', 'on edge', 'spiral']
make_confusion_matrix(conf_mat,
                      categories=categories)

from sklearn.metrics import recall_score
print("Recall: ", recall_score(testovacia, predikovana, average=None))

print("Precision: ", precision_score(testovacia, predikovana, average=None))

from sklearn.metrics import classification_report
print(classification_report(testovacia, predikovana, target_names=categories))
# Out:
# [[1552  107    0   41]
#  [  33 1461   10   42]
#  [   1   12 1017   10]
#  [  28   47   36 1992]]
# Recall:  [0.91294118 0.9450194  0.97788462 0.94721826]
# Precision:  [0.96158612 0.89797173 0.95672625 0.95539568]
#                   precision    recall  f1-score   support
#
# completely round       0.96      0.91      0.94      1700
#       in between       0.90      0.95      0.92      1546
#          on edge       0.96      0.98      0.97      1040
#           spiral       0.96      0.95      0.95      2103
#
#         accuracy                           0.94      6389
#        macro avg       0.94      0.95      0.94      6389
#     weighted avg       0.94      0.94      0.94      6389

# %%
import os
print("TRENOVACIA mnozina vytvorena, velkost: ", len(os.listdir('./trenovacie_data_nad_80')))
# Out:
# TRENOVACIA mnozina vytvorena, velkost:  20412
